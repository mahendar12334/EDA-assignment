# %% [markdown]
# # Exploratory Data Analysis 1

# %%
#load the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# from google.colab import files
# uploaded = files.upload()

# %%
data = pd.read_csv("data_clean.csv")
data
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
data.tail()
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C

# %%
data
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
# Display all the rows and columns using pd.set_option
# pd.set_option('display.max_rows',200,'display.max_columns',20)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  158 non-null    int64
#  1   Ozone       120 non-null    float64
#  2   Solar.R     151 non-null    float64
#  3   Wind        158 non-null    float64
#  4   Temp C      158 non-null    object
#  5   Month       158 non-null    object
#  6   Day         158 non-null    int64
#  7   Year        158 non-null    int64
#  8   Temp        158 non-null    int64
#  9   Weather     155 non-null    object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 12.5+ KB

# %%
data
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
#Data Structure 
print(type(data))
print(data.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (158, 10)

# %%
data.shape
# Out:
# (158, 10)

# %%
#data types
data.dtypes
# Out:
# Unnamed: 0      int64
# Ozone         float64
# Solar.R       float64
# Wind          float64
# Temp C         object
# Month          object
# Day             int64
# Year            int64
# Temp            int64
# Weather        object
# dtype: object

# %%
data.describe()
# Out:
#        Unnamed: 0       Ozone     Solar.R        Wind         Day    Year  \
# count  158.000000  120.000000  151.000000  158.000000  158.000000   158.0
# mean    79.500000   41.583333  185.403974    9.957595   16.006329  2010.0
# std     45.754781   32.620709   88.723103    3.511261    8.997166     0.0
# min      1.000000    1.000000    7.000000    1.700000    1.000000  2010.0
# 25%     40.250000   18.000000  119.000000    7.400000    8.000000  2010.0
# 50%     79.500000   30.500000  197.000000    9.700000   16.000000  2010.0
# 75%    118.750000   61.500000  257.000000   11.875000   24.000000  2010.0
# max    158.000000  168.000000  334.000000   20.700000   31.000000  2010.0
#
#              Temp
# count  158.000000
# mean    77.727848
# std      9.377877
# min     56.000000
# 25%     72.000000
# 50%     78.500000
# 75%     84.000000
# max     97.000000

# %%
sns.histplot(data["Solar.R"], kde=True)
# Out:
# <Axes: xlabel='Solar.R', ylabel='Count'>

# %%
sns.boxplot(data["Solar.R"], orient ='h')
# Out:
# <Axes: >

# %%
data.describe(include="all")
# Out:
#         Unnamed: 0       Ozone     Solar.R        Wind Temp C Month  \
# count   158.000000  120.000000  151.000000  158.000000    158   158
# unique         NaN         NaN         NaN         NaN     41     6
# top            NaN         NaN         NaN         NaN     81     9
# freq           NaN         NaN         NaN         NaN     11    34
# mean     79.500000   41.583333  185.403974    9.957595    NaN   NaN
# std      45.754781   32.620709   88.723103    3.511261    NaN   NaN
# min       1.000000    1.000000    7.000000    1.700000    NaN   NaN
# 25%      40.250000   18.000000  119.000000    7.400000    NaN   NaN
# 50%      79.500000   30.500000  197.000000    9.700000    NaN   NaN
# 75%     118.750000   61.500000  257.000000   11.875000    NaN   NaN
# max     158.000000  168.000000  334.000000   20.700000    NaN   NaN
#
#                Day    Year        Temp Weather
# count   158.000000   158.0  158.000000     155
# unique         NaN     NaN         NaN       3
# ...

# %%
# Select only the categorical variables from your DataFrame
categorical_df = data.select_dtypes(include=['object'])

# Generate descriptive statistics for categorical variables
categorical_stats = categorical_df.describe()

print(categorical_stats)
# Out:
#        Temp C Month Weather
# count     158   158     155
# unique     41     6       3
# top        81     9       S
# freq       11    34      59

# %% [markdown]
# # Data type conversion

# %%
data.head(50)
# Out:
#     Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0            1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1            2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2            3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3            4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4            5    NaN      NaN  14.3     56     5    5  2010    56       S
# 5            6   28.0      NaN  14.9     66     5    6  2010    66       C
# 6            7   23.0    299.0   8.6     65     5    7  2010    65      PS
# 7            8   19.0     99.0  13.8     59     5    8  2010    59       C
# 8            9    8.0     19.0  20.1     61     5    9  2010    61      PS
# 9           10    NaN    194.0   8.6     69     5   10  2010    69       S
# 10          11    7.0      NaN   6.9      C     5   11  2010    74       C
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  158 non-null    int64
#  1   Ozone       120 non-null    float64
#  2   Solar.R     151 non-null    float64
#  3   Wind        158 non-null    float64
#  4   Temp C      158 non-null    object
#  5   Month       158 non-null    object
#  6   Day         158 non-null    int64
#  7   Year        158 non-null    int64
#  8   Temp        158 non-null    int64
#  9   Weather     155 non-null    object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 12.5+ KB

# %%
data['Month']=pd.to_numeric(data['Month'],errors='coerce') #[1,1.5,NAN] january NA
data['Temp C']=pd.to_numeric(data['Temp C'],errors='coerce')# coerce will introduce NA values for non numeric data in the columns
data['Weather']=data['Weather'].astype('category')           #data['Wind']=data['Wind'].astype('int64')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  158 non-null    int64
#  1   Ozone       120 non-null    float64
#  2   Solar.R     151 non-null    float64
#  3   Wind        158 non-null    float64
#  4   Temp C      157 non-null    float64
#  5   Month       157 non-null    float64
#  6   Day         158 non-null    int64
#  7   Year        158 non-null    int64
#  8   Temp        158 non-null    int64
#  9   Weather     155 non-null    category
# dtypes: category(1), float64(5), int64(4)
# memory usage: 11.5 KB

# %% [markdown]
# ### Drop Columns

# %%
data.head()
# Out:
#    Unnamed: 0  Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 0           1   41.0    190.0   7.4    67.0    5.0    1  2010    67       S
# 1           2   36.0    118.0   8.0    72.0    5.0    2  2010    72       C
# 2           3   12.0    149.0  12.6    74.0    5.0    3  2010    74      PS
# 3           4   18.0    313.0  11.5    62.0    5.0    4  2010    62       S
# 4           5    NaN      NaN  14.3    56.0    5.0    5  2010    56       S

# %%
data1 = data.drop('Unnamed: 0',axis=1)

# %%
data
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4    67.0    5.0    1  2010    67       S
# 1             2   36.0    118.0   8.0    72.0    5.0    2  2010    72       C
# 2             3   12.0    149.0  12.6    74.0    5.0    3  2010    74      PS
# 3             4   18.0    313.0  11.5    62.0    5.0    4  2010    62       S
# 4             5    NaN      NaN  14.3    56.0    5.0    5  2010    56       S
# ..          ...    ...      ...   ...     ...    ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4    67.0    5.0    1  2010    67       C
# 154         155   30.0    193.0   6.9    70.0    9.0   26  2010    70      PS
# 155         156    NaN    145.0  13.2    77.0    9.0   27  2010    77       S
# 156         157   14.0    191.0  14.3    75.0    9.0   28  2010    75       S
# 157         158   18.0    131.0   8.0    76.0    9.0   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
data1
# Out:
#      Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4    67.0    5.0    1  2010    67       S
# 1     36.0    118.0   8.0    72.0    5.0    2  2010    72       C
# 2     12.0    149.0  12.6    74.0    5.0    3  2010    74      PS
# 3     18.0    313.0  11.5    62.0    5.0    4  2010    62       S
# 4      NaN      NaN  14.3    56.0    5.0    5  2010    56       S
# ..     ...      ...   ...     ...    ...  ...   ...   ...     ...
# 153   41.0    190.0   7.4    67.0    5.0    1  2010    67       C
# 154   30.0    193.0   6.9    70.0    9.0   26  2010    70      PS
# 155    NaN    145.0  13.2    77.0    9.0   27  2010    77       S
# 156   14.0    191.0  14.3    75.0    9.0   28  2010    75       S
# 157   18.0    131.0   8.0    76.0    9.0   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
data.drop([0,1]) # dropping rows
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 2             3   12.0    149.0  12.6    74.0    5.0    3  2010    74      PS
# 3             4   18.0    313.0  11.5    62.0    5.0    4  2010    62       S
# 4             5    NaN      NaN  14.3    56.0    5.0    5  2010    56       S
# 5             6   28.0      NaN  14.9    66.0    5.0    6  2010    66       C
# 6             7   23.0    299.0   8.6    65.0    5.0    7  2010    65      PS
# ..          ...    ...      ...   ...     ...    ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4    67.0    5.0    1  2010    67       C
# 154         155   30.0    193.0   6.9    70.0    9.0   26  2010    70      PS
# 155         156    NaN    145.0  13.2    77.0    9.0   27  2010    77       S
# 156         157   14.0    191.0  14.3    75.0    9.0   28  2010    75       S
# 157         158   18.0    131.0   8.0    76.0    9.0   29  2010    76       C
#
# [156 rows x 10 columns]

# %%
data1
# Out:
#      Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4    67.0    5.0    1  2010    67       S
# 1     36.0    118.0   8.0    72.0    5.0    2  2010    72       C
# 2     12.0    149.0  12.6    74.0    5.0    3  2010    74      PS
# 3     18.0    313.0  11.5    62.0    5.0    4  2010    62       S
# 4      NaN      NaN  14.3    56.0    5.0    5  2010    56       S
# ..     ...      ...   ...     ...    ...  ...   ...   ...     ...
# 153   41.0    190.0   7.4    67.0    5.0    1  2010    67       C
# 154   30.0    193.0   6.9    70.0    9.0   26  2010    70      PS
# 155    NaN    145.0  13.2    77.0    9.0   27  2010    77       S
# 156   14.0    191.0  14.3    75.0    9.0   28  2010    75       S
# 157   18.0    131.0   8.0    76.0    9.0   29  2010    76       C
#
# [158 rows x 9 columns]

# %% [markdown]
# ### Remove duplicated rows

# %%
data1.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 153    False
# 154    False
# 155    False
# 156     True
# 157    False
# Length: 158, dtype: bool

# %%
data1.iloc[140:157]
# Out:
#      Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 140   13.0     27.0  10.3    76.0    9.0   18  2010    76       S
# 141   24.0    238.0  10.3    68.0    9.0   19  2010    68       C
# 142   16.0    201.0   8.0    82.0    9.0   20  2010    82      PS
# 143   13.0    238.0  12.6    64.0    9.0   21  2010    64      PS
# 144   23.0     14.0   9.2    71.0    9.0   22  2010    71       S
# 145   36.0    139.0  10.3    81.0    9.0   23  2010    81       S
# 146    7.0     49.0  10.3    69.0    9.0   24  2010    69       C
# 147   14.0     20.0  16.6    63.0    9.0   25  2010    63      PS
# 148   30.0    193.0   6.9    70.0    9.0   26  2010    70       C
# 149    NaN    145.0  13.2    77.0    9.0   27  2010    77      PS
# 150   14.0    191.0  14.3    75.0    9.0   28  2010    75       S
# 151   18.0    131.0   8.0    76.0    9.0   29  2010    76      PS
# 152   20.0    223.0  11.5    68.0    9.0   30  2010    68       S
# ...

# %%
data1.loc[157] = [14.0,191.0,14.3,75.0,9.0,28,2010,75,'S']

# %%
data1
# Out:
#      Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4    67.0    5.0    1  2010    67       S
# 1     36.0    118.0   8.0    72.0    5.0    2  2010    72       C
# 2     12.0    149.0  12.6    74.0    5.0    3  2010    74      PS
# 3     18.0    313.0  11.5    62.0    5.0    4  2010    62       S
# 4      NaN      NaN  14.3    56.0    5.0    5  2010    56       S
# ..     ...      ...   ...     ...    ...  ...   ...   ...     ...
# 153   41.0    190.0   7.4    67.0    5.0    1  2010    67       C
# 154   30.0    193.0   6.9    70.0    9.0   26  2010    70      PS
# 155    NaN    145.0  13.2    77.0    9.0   27  2010    77       S
# 156   14.0    191.0  14.3    75.0    9.0   28  2010    75       S
# 157   14.0    191.0  14.3    75.0    9.0   28  2010    75       S
#
# [158 rows x 9 columns]

# %%
#Print the duplicated rows
data1[data1.duplicated(keep=False)]
# Out:
#      Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 150   14.0    191.0  14.3    75.0    9.0   28  2010    75       S
# 156   14.0    191.0  14.3    75.0    9.0   28  2010    75       S
# 157   14.0    191.0  14.3    75.0    9.0   28  2010    75       S

# %%
data1[data1.duplicated(keep="first")]
# Out:
#      Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 156   14.0    191.0  14.3    75.0    9.0   28  2010    75       S
# 157   14.0    191.0  14.3    75.0    9.0   28  2010    75       S

# %%
data1[data1.duplicated(keep="last")]
# Out:
#      Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 150   14.0    191.0  14.3    75.0    9.0   28  2010    75       S
# 156   14.0    191.0  14.3    75.0    9.0   28  2010    75       S

# %%
data_cleaned1=data1.drop_duplicates(keep="first")

# %%
data_cleaned1[data_cleaned1.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Ozone, Solar.R, Wind, Temp C, Month, Day, Year, Temp, Weather]
# Index: []

# %%
data1.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 153    False
# 154    False
# 155    False
# 156     True
# 157     True
# Length: 158, dtype: bool

# %% [markdown]
# # Drop columns

# %%
data_cleaned1
# Out:
#      Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4    67.0    5.0    1  2010    67       S
# 1     36.0    118.0   8.0    72.0    5.0    2  2010    72       C
# 2     12.0    149.0  12.6    74.0    5.0    3  2010    74      PS
# 3     18.0    313.0  11.5    62.0    5.0    4  2010    62       S
# 4      NaN      NaN  14.3    56.0    5.0    5  2010    56       S
# ..     ...      ...   ...     ...    ...  ...   ...   ...     ...
# 152   20.0    223.0  11.5    68.0    9.0   30  2010    68       S
# 153   41.0    190.0   7.4    67.0    5.0    1  2010    67       C
# 154   30.0    193.0   6.9    70.0    9.0   26  2010    70      PS
# 155    NaN    145.0  13.2    77.0    9.0   27  2010    77       S
# 157   18.0    131.0   8.0    76.0    9.0   29  2010    76       C
#
# [157 rows x 9 columns]

# %%
# data_cleaned1["Temp C"] == data_cleaned1["Temp"]

# %%
# for i in range(len(data_cleaned1)):
#     if  (data_cleaned1["Temp C"][i] == data_cleaned1["Temp"][i]):
#         print(True)
#     else:
#         print ("Unmatched")
#         break

# %%
# data_cleaned1.drop('Temp C',axis=1, inplace =True)

# %%
data_cleaned2=data_cleaned1.drop('Temp C',axis=1)

# %%
data_cleaned2
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4    5.0    1  2010    67       S
# 1     36.0    118.0   8.0    5.0    2  2010    72       C
# 2     12.0    149.0  12.6    5.0    3  2010    74      PS
# 3     18.0    313.0  11.5    5.0    4  2010    62       S
# 4      NaN      NaN  14.3    5.0    5  2010    56       S
# ..     ...      ...   ...    ...  ...   ...   ...     ...
# 151   18.0    131.0   8.0    9.0   29  2010    76      PS
# 152   20.0    223.0  11.5    9.0   30  2010    68       S
# 153   41.0    190.0   7.4    5.0    1  2010    67       C
# 154   30.0    193.0   6.9    9.0   26  2010    70      PS
# 155    NaN    145.0  13.2    9.0   27  2010    77       S
#
# [156 rows x 8 columns]

# %% [markdown]
# # Rename the columns

# %%
#rename the Solar column
data_cleaned3 = data_cleaned2.rename({'Solar.R': 'Solar'}, axis=1)

# %%
data_cleaned3.head()
# Out:
#    Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 0   41.0  190.0   7.4    5.0    1  2010    67       S
# 1   36.0  118.0   8.0    5.0    2  2010    72       C
# 2   12.0  149.0  12.6    5.0    3  2010    74      PS
# 3   18.0  313.0  11.5    5.0    4  2010    62       S
# 4    NaN    NaN  14.3    5.0    5  2010    56       S

# %%
data_cleaned3.columns
# Out:
# Index(['Ozone', 'Solar', 'Wind', 'Month', 'Day', 'Year', 'Temp', 'Weather'], dtype='object')

# %%
data_cleaned3.columns = ['Ozone', 'Solar', 'Wind', 'Month', 'Day', 'Year', 'Temperature', 'Weather']

# %%
data_cleaned3
# Out:
#      Ozone  Solar  Wind  Month  Day  Year  Temperature Weather
# 0     41.0  190.0   7.4    5.0    1  2010           67       S
# 1     36.0  118.0   8.0    5.0    2  2010           72       C
# 2     12.0  149.0  12.6    5.0    3  2010           74      PS
# 3     18.0  313.0  11.5    5.0    4  2010           62       S
# 4      NaN    NaN  14.3    5.0    5  2010           56       S
# ..     ...    ...   ...    ...  ...   ...          ...     ...
# 151   18.0  131.0   8.0    9.0   29  2010           76      PS
# 152   20.0  223.0  11.5    9.0   30  2010           68       S
# 153   41.0  190.0   7.4    5.0    1  2010           67       C
# 154   30.0  193.0   6.9    9.0   26  2010           70      PS
# 155    NaN  145.0  13.2    9.0   27  2010           77       S
#
# [156 rows x 8 columns]

# %%
data_cleaned3.columns = ['Ozone', 'Solar', 'Wind', 'Month', 'Day', 'Year', 'Temp', 'Weather']

# %% [markdown]
# # Missing Values and Imputation

# %%
data_cleaned3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 157 entries, 0 to 157
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    119 non-null    float64
#  1   Solar    150 non-null    float64
#  2   Wind     157 non-null    float64
#  3   Month    156 non-null    float64
#  4   Day      157 non-null    int64
#  5   Year     157 non-null    int64
#  6   Temp     157 non-null    int64
#  7   Weather  154 non-null    category
# dtypes: category(1), float64(4), int64(3)
# memory usage: 10.1 KB

# %%
import seaborn as sns
cols = data_cleaned3.columns 
colours = ['black', 'yellow'] # specify the colours - yellow is missing. blue is not missing.
sns.heatmap(data_cleaned3[cols].isnull(),
            cmap=sns.color_palette(colours), cbar = True)
# Out:
# <Axes: >

# %%
data_cleaned3.isnull().any(axis=1)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 152    False
# 153    False
# 154    False
# 155     True
# 157    False
# Length: 157, dtype: bool

# %%
data_cleaned3.isnull().sum()
# Out:
# Ozone          38
# Solar           7
# Wind            0
# Month           1
# Day             0
# Year            0
# Temperature     0
# Weather         3
# dtype: int64

# %%
data_cleaned3[data_cleaned3.isnull().any(axis=1)]
# Out:
#      Ozone  Solar  Wind  Month  Day  Year  Temperature Weather
# 4      NaN    NaN  14.3    5.0    5  2010           56       S
# 5     28.0    NaN  14.9    5.0    6  2010           66       C
# 9      NaN  194.0   8.6    5.0   10  2010           69       S
# 10     7.0    NaN   6.9    5.0   11  2010           74       C
# 23    32.0   92.0  12.0    NaN   24  2010           61       C
# 24     NaN   66.0  16.6    5.0   25  2010           57      PS
# 25     NaN  266.0  14.9    5.0   26  2010           58       C
# 26     NaN    NaN   8.0    5.0   27  2010           57      PS
# 31     NaN  286.0   8.6    6.0    1  2010           78       S
# 32     NaN  287.0   9.7    6.0    2  2010           74       C
# 33     NaN  242.0  16.1    6.0    3  2010           67      PS
# 34     NaN  186.0   9.2    6.0    4  2010           84       C
# 35     NaN  220.0   8.6    6.0    5  2010           85      PS
# 36     NaN  264.0  14.3    6.0    6  2010           79       C
# ...

# %%
# data_of_nulls = data_cleaned3[cols].isnull()
# column_names = list(data_cleaned3.columns)

# data_of_nulls

# %%
# for i in column_names:
#   if True in list(data_of_nulls[i]):
#     print(i)

# %%
data_cleaned3.isnull().sum()
# Out:
# Ozone      38
# Solar       7
# Wind        0
# Month       1
# Day         0
# Year        0
# Temp        0
# Weather     3
# dtype: int64

# %%
data_cleaned3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 157 entries, 0 to 157
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    119 non-null    float64
#  1   Solar    150 non-null    float64
#  2   Wind     157 non-null    float64
#  3   Month    156 non-null    float64
#  4   Day      157 non-null    int64
#  5   Year     157 non-null    int64
#  6   Temp     157 non-null    int64
#  7   Weather  154 non-null    category
# dtypes: category(1), float64(4), int64(3)
# memory usage: 14.2 KB

# %%
#Imputation of missing value with median
median = data_cleaned3["Ozone"].median()
print(median)
# Out:
# 31.5

# %%
data_cleaned3['Ozone'] = data_cleaned3['Ozone'].fillna(median)

# %%
data_cleaned3
# Out:
#      Ozone  Solar  Wind  Month  Day  Year  Temperature Weather
# 0     41.0  190.0   7.4    5.0    1  2010           67       S
# 1     36.0  118.0   8.0    5.0    2  2010           72       C
# 2     12.0  149.0  12.6    5.0    3  2010           74      PS
# 3     18.0  313.0  11.5    5.0    4  2010           62       S
# 4     31.5    NaN  14.3    5.0    5  2010           56       S
# ..     ...    ...   ...    ...  ...   ...          ...     ...
# 151   18.0  131.0   8.0    9.0   29  2010           76      PS
# 152   20.0  223.0  11.5    9.0   30  2010           68       S
# 153   41.0  190.0   7.4    5.0    1  2010           67       C
# 154   30.0  193.0   6.9    9.0   26  2010           70      PS
# 155   31.5  145.0  13.2    9.0   27  2010           77       S
#
# [156 rows x 8 columns]

# %%
data_cleaned3.isnull().sum()
# Out:
# Ozone      0
# Solar      7
# Wind       0
# Month      1
# Day        0
# Year       0
# Temp       0
# Weather    3
# dtype: int64

# %%
# Treat missing values in categorical column
data_cleaned3["Weather"].value_counts()
# Out:
# S     58
# C     49
# PS    47
# Name: Weather, dtype: int64

# %%
mode = data_cleaned3["Weather"].mode()[0]
mode
# Out:
# 'S'

# %%
data_cleaned3["Weather"] = data_cleaned3["Weather"].fillna(mode)

# %%
data_cleaned3
# Out:
#      Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 0     41.0  190.0   7.4    5.0    1  2010    67       S
# 1     36.0  118.0   8.0    5.0    2  2010    72       C
# 2     12.0  149.0  12.6    5.0    3  2010    74      PS
# 3     18.0  313.0  11.5    5.0    4  2010    62       S
# 4     31.0    NaN  14.3    5.0    5  2010    56       S
# ..     ...    ...   ...    ...  ...   ...   ...     ...
# 152   20.0  223.0  11.5    9.0   30  2010    68       S
# 153   41.0  190.0   7.4    5.0    1  2010    67       C
# 154   30.0  193.0   6.9    9.0   26  2010    70      PS
# 155   31.0  145.0  13.2    9.0   27  2010    77       S
# 157   18.0  131.0   8.0    9.0   29  2010    76       C
#
# [157 rows x 8 columns]

# %%
data_cleaned3["Weather"].isnull().sum()
# Out:
# 0

# %% [markdown]
# # Outlier Detection

# %%
data_cleaned3
# Out:
#      Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 0     41.0  190.0   7.4    5.0    1  2010    67       S
# 1     36.0  118.0   8.0    5.0    2  2010    72       C
# 2     12.0  149.0  12.6    5.0    3  2010    74      PS
# 3     18.0  313.0  11.5    5.0    4  2010    62       S
# 4     31.0    NaN  14.3    5.0    5  2010    56       S
# ..     ...    ...   ...    ...  ...   ...   ...     ...
# 152   20.0  223.0  11.5    9.0   30  2010    68       S
# 153   41.0  190.0   7.4    5.0    1  2010    67       C
# 154   30.0  193.0   6.9    9.0   26  2010    70      PS
# 155   31.0  145.0  13.2    9.0   27  2010    77       S
# 157   18.0  131.0   8.0    9.0   29  2010    76       C
#
# [157 rows x 8 columns]

# %%
# histogram of Ozone
data_cleaned3['Ozone'].hist()
# Out:
# <Axes: >

# %%
# #Box plot

plt.boxplot(data_cleaned3["Ozone"],vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x26de8575850>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x26de86ee8d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x26de7730850>],
#  'medians': [<matplotlib.lines.Line2D at 0x26de86efdd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x26de8632a50>],
#  'means': []}

# %%
import seaborn as sns
sns.boxplot(data_cleaned3['Ozone'], orient='h')
# Out:
# <Axes: >

# %%
# Extracting outliers
plt.grid()
box = plt.boxplot(data_cleaned3['Ozone'],vert=False)

# %%
type(box)
# Out:
# dict

# %%
# d1 = {'name':['Ram','John','Ramesh'],'Age':[30,40,35]}
# for p,q in d1.items():
#     print(p,q)
# Out:
# name ['Ram', 'John', 'Ramesh']
# Age [30, 40, 35]

# %%
box
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x26de8757e90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x26de8769690>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x26de87573d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x26de876ad50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x26de8720cd0>],
#  'means': []}

# %%
for i,j in box.items():
    print(i,j)
# Out:
# whiskers [<matplotlib.lines.Line2D object at 0x00000202483C0A10>, <matplotlib.lines.Line2D object at 0x00000202483C0FD0>]
# caps [<matplotlib.lines.Line2D object at 0x00000202483C1E90>, <matplotlib.lines.Line2D object at 0x00000202483C2A50>]
# boxes [<matplotlib.lines.Line2D object at 0x0000020248379E50>]
# medians [<matplotlib.lines.Line2D object at 0x00000202483C34D0>]
# fliers [<matplotlib.lines.Line2D object at 0x00000202483C3F50>]
# means []

# %%
[item.get_xdata() for item in box['fliers']] #fliers are outliers
# Out:
# [array([115., 135.,  97.,  97.,  85., 108.,  82., 122.,  89., 110., 168.,
#         118.,  84.,  85.,  96.,  91.])]

# %%
#To get the whiskers
[item.get_xdata() for item in box['whiskers']]
# Out:
# [array([21.,  1.]), array([45., 80.])]

# %%
# Printing outliers using standard deviation and assuming a normal distribution
for x in data_cleaned3["Ozone"]:
    mean = data_cleaned3["Ozone"].mean()
    std = data_cleaned3["Ozone"].std()
    if (x<(mean-3*std)) or (x > (mean+3*std)):
        print(x, end=' ')
# Out:
# 135.0 168.0

# %%
data_cleaned3.to_csv("data_3.csv")

# %%
#Descriptive stat
data_cleaned3['Ozone'].describe()
# Out:
# count    157.000000
# mean      39.197452
# std       28.781992
# min        1.000000
# 25%       21.000000
# 50%       31.000000
# 75%       45.000000
# max      168.000000
# Name: Ozone, dtype: float64

# %%
data_cleaned3
# Out:
#      Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 0     41.0  190.0   7.4    5.0    1  2010    67       S
# 1     36.0  118.0   8.0    5.0    2  2010    72       C
# 2     12.0  149.0  12.6    5.0    3  2010    74      PS
# 3     18.0  313.0  11.5    5.0    4  2010    62       S
# 4     31.0    NaN  14.3    5.0    5  2010    56       S
# ..     ...    ...   ...    ...  ...   ...   ...     ...
# 152   20.0  223.0  11.5    9.0   30  2010    68       S
# 153   41.0  190.0   7.4    5.0    1  2010    67       C
# 154   30.0  193.0   6.9    9.0   26  2010    70      PS
# 155   31.0  145.0  13.2    9.0   27  2010    77       S
# 157   18.0  131.0   8.0    9.0   29  2010    76       C
#
# [157 rows x 8 columns]

# %%
import pandas as pd

# Display all the rows and columns using pd.set_option
pd.set_option('display.max_rows',200,'display.max_columns',20)

# %%
# Reset display options to default
pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')

# %%
data_cleaned3
# Out:
#      Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 0     41.0  190.0   7.4    5.0    1  2010    67       S
# 1     36.0  118.0   8.0    5.0    2  2010    72       C
# 2     12.0  149.0  12.6    5.0    3  2010    74      PS
# 3     18.0  313.0  11.5    5.0    4  2010    62       S
# 4     31.0    NaN  14.3    5.0    5  2010    56       S
# ..     ...    ...   ...    ...  ...   ...   ...     ...
# 152   20.0  223.0  11.5    9.0   30  2010    68       S
# 153   41.0  190.0   7.4    5.0    1  2010    67       C
# 154   30.0  193.0   6.9    9.0   26  2010    70      PS
# 155   31.0  145.0  13.2    9.0   27  2010    77       S
# 157   18.0  131.0   8.0    9.0   29  2010    76       C
#
# [157 rows x 8 columns]

# %%
data_cleaned3["Weather"].value_counts()
# Out:
# S     61
# C     49
# PS    47
# Name: Weather, dtype: int64

# %% [markdown]
# # Scatter plot and Correlation analysis

# %%
hw = pd.DataFrame()
hw["Height"]=[165,180,145,167,156,175,150,162,172]
hw["Weight"]=[65,80,55,67,56,75, 67,78,89]
hw
# Out:
#    Height  Weight
# 0     165      65
# 1     180      80
# 2     145      55
# 3     167      67
# 4     156      56
# 5     175      75
# 6     150      67
# 7     162      78
# 8     172      89

# %%
plt.scatter(hw["Height"], hw["Weight"])

# %%
hw.corr()
# Out:
#          Height   Weight
# Height  1.00000  0.74454
# Weight  0.74454  1.00000

# %%
# Seaborn visualization library
import seaborn as sns
# Create the default pairplot
#pd.plotting.scatter_matrix(data_cleaned3)
sns.pairplot(data_cleaned3.iloc[:,0:8], dropna=True)

# %%
sns.scatterplot(data =data_cleaned3, x= data_cleaned3["Solar"], y= data_cleaned3["Day"])
# Out:
# <Axes: xlabel='Solar', ylabel='Day'>

# %%
import matplotlib.pyplot as plt
plt.scatter(data_cleaned3["Ozone"], data_cleaned3["Solar"])

# %%
data_cleaned3[["Solar","Ozone"]].corr()
# Out:
#           Solar     Ozone
# Solar  1.000000  0.301821
# Ozone  0.301821  1.000000

# %%
data_cleaned3.corr()
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_16108\496522264.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data_cleaned3.corr()
#           Ozone     Solar      Wind     Month       Day  Year      Temp
# Ozone  1.000000  0.301821 -0.523738  0.170343 -0.031737   NaN  0.597087
# Solar  0.301821  1.000000 -0.057407 -0.094012 -0.155663   NaN  0.273558
# Wind  -0.523738 -0.057407  1.000000 -0.166216  0.029900   NaN -0.441228
# Month  0.170343 -0.094012 -0.166216  1.000000  0.050055   NaN  0.398516
# Day   -0.031737 -0.155663  0.029900  0.050055  1.000000   NaN -0.122787
# Year        NaN       NaN       NaN       NaN       NaN   NaN       NaN
# Temp   0.597087  0.273558 -0.441228  0.398516 -0.122787   NaN  1.000000

# %%
data_cleaned3.head(3)
# Out:
#    Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 0   41.0  190.0   7.4    5.0    1  2010    67       S
# 1   36.0  118.0   8.0    5.0    2  2010    72       C
# 2   12.0  149.0  12.6    5.0    3  2010    74      PS

# %%
#Correlation
data_cleaned3.corr(numeric_only=True)
# Out:
#           Ozone     Solar      Wind     Month       Day  Year      Temp
# Ozone  1.000000  0.301821 -0.523738  0.170343 -0.031737   NaN  0.597087
# Solar  0.301821  1.000000 -0.057407 -0.094012 -0.155663   NaN  0.273558
# Wind  -0.523738 -0.057407  1.000000 -0.166216  0.029900   NaN -0.441228
# Month  0.170343 -0.094012 -0.166216  1.000000  0.050055   NaN  0.398516
# Day   -0.031737 -0.155663  0.029900  0.050055  1.000000   NaN -0.122787
# Year        NaN       NaN       NaN       NaN       NaN   NaN       NaN
# Temp   0.597087  0.273558 -0.441228  0.398516 -0.122787   NaN  1.000000

# %% [markdown]
# # Transformations

# %% [markdown]
# #### Dummy Variable

# %%
data_cleaned3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 157 entries, 0 to 157
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    157 non-null    float64
#  1   Solar    150 non-null    float64
#  2   Wind     157 non-null    float64
#  3   Month    156 non-null    float64
#  4   Day      157 non-null    int64
#  5   Year     157 non-null    int64
#  6   Temp     157 non-null    int64
#  7   Weather  157 non-null    category
# dtypes: category(1), float64(4), int64(3)
# memory usage: 14.2 KB

# %%
data_cleaned3
# Out:
#      Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 0     41.0  190.0   7.4    5.0    1  2010    67       S
# 1     36.0  118.0   8.0    5.0    2  2010    72       C
# 2     12.0  149.0  12.6    5.0    3  2010    74      PS
# 3     18.0  313.0  11.5    5.0    4  2010    62       S
# 4     31.0    NaN  14.3    5.0    5  2010    56       S
# ..     ...    ...   ...    ...  ...   ...   ...     ...
# 152   20.0  223.0  11.5    9.0   30  2010    68       S
# 153   41.0  190.0   7.4    5.0    1  2010    67       C
# 154   30.0  193.0   6.9    9.0   26  2010    70      PS
# 155   31.0  145.0  13.2    9.0   27  2010    77       S
# 157   18.0  131.0   8.0    9.0   29  2010    76       C
#
# [157 rows x 8 columns]

# %%
data_cleaned3["Weather"].value_counts()
# Out:
# S     61
# C     49
# PS    47
# Name: Weather, dtype: int64

# %%
#Creating dummy variable for Weather column
data_cleaned4=pd.get_dummies(data_cleaned3,columns=['Weather'])

# %%
data_cleaned4
# Out:
#      Ozone  Solar  Wind  Month  Day  Year  Temp  Weather_C  Weather_PS  \
# 0     41.0  190.0   7.4    5.0    1  2010    67          0           0
# 1     36.0  118.0   8.0    5.0    2  2010    72          1           0
# 2     12.0  149.0  12.6    5.0    3  2010    74          0           1
# 3     18.0  313.0  11.5    5.0    4  2010    62          0           0
# 4     31.0    NaN  14.3    5.0    5  2010    56          0           0
# ..     ...    ...   ...    ...  ...   ...   ...        ...         ...
# 152   20.0  223.0  11.5    9.0   30  2010    68          0           0
# 153   41.0  190.0   7.4    5.0    1  2010    67          1           0
# 154   30.0  193.0   6.9    9.0   26  2010    70          0           1
# 155   31.0  145.0  13.2    9.0   27  2010    77          0           0
# 157   18.0  131.0   8.0    9.0   29  2010    76          1           0
#
#      Weather_S
# 0            1
# 1            0
# 2            0
# 3            1
# 4            1
# ..         ...
# ...

# %%
data_cleaned4=data_cleaned4.dropna()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
data_cleaned3["Weather"] = LabelEncoder().fit_transform(data_cleaned3["Weather"])

# %%
data_cleaned3
# Out:
#      Ozone  Solar  Wind  Month  Day  Year  Temp  Weather
# 0     41.0  190.0   7.4    5.0    1  2010    67        2
# 1     36.0  118.0   8.0    5.0    2  2010    72        0
# 2     12.0  149.0  12.6    5.0    3  2010    74        1
# 3     18.0  313.0  11.5    5.0    4  2010    62        2
# 4     31.0    NaN  14.3    5.0    5  2010    56        2
# ..     ...    ...   ...    ...  ...   ...   ...      ...
# 152   20.0  223.0  11.5    9.0   30  2010    68        2
# 153   41.0  190.0   7.4    5.0    1  2010    67        0
# 154   30.0  193.0   6.9    9.0   26  2010    70        1
# 155   31.0  145.0  13.2    9.0   27  2010    77        2
# 157   18.0  131.0   8.0    9.0   29  2010    76        0
#
# [157 rows x 8 columns]

# %% [markdown]
# ### Normalization of Data
# Normalization of data is a technique used to modify the values in the dataset to achieve a common scale, without distorting differences in the ranges of values or losing information. This is particularly important in data analysis and machine learning where different variables may operate on completely different scales (e.g., age in years versus income in dollars). Normalization helps algorithms to converge faster and perform better.
#
# Common methods of normalization include:
#
# 1. Min-Max Normalization: This scales all the data between 0 and 1. The formula for Min-Max normalization is given by:
# $$ x' = \frac{x - \min(x)}{\max(x) - \min(x)} $$
#
# 2. Z-score Normalization (Standardization): This method scales the data so that the mean of the transformed data is 0 and the standard deviation is 1. The formula is:
# $$ x' = \frac{x - \mu}{\sigma} $$
#
# where x is the original value,μ is the mean of the data, and σ is the standard deviation.

# %% [markdown]
# #### Normalization of the data using MinMaxScaler()

# %%
#Normalization of the data
from numpy import set_printoptions
from sklearn.preprocessing import MinMaxScaler

# %%
data_cleaned4.values
# Out:
# array([[ 41. , 190. ,   7.4, ...,   0. ,   0. ,   1. ],
#        [ 36. , 118. ,   8. , ...,   1. ,   0. ,   0. ],
#        [ 12. , 149. ,  12.6, ...,   0. ,   1. ,   0. ],
#        ...,
#        [ 30. , 193. ,   6.9, ...,   0. ,   1. ,   0. ],
#        [ 31. , 145. ,  13.2, ...,   0. ,   0. ,   1. ],
#        [ 18. , 131. ,   8. , ...,   1. ,   0. ,   0. ]])

# %%
array = data_cleaned4.values

scaler = MinMaxScaler(feature_range=(0,1))
rescaledX = scaler.fit_transform(array)

#transformed data
set_printoptions(precision=2)
print(rescaledX[0:5,:])
# Out:
# [[0.24 0.56 0.3  0.   0.   0.   0.25 0.   0.   1.  ]
#  [0.21 0.34 0.33 0.   0.03 0.   0.38 1.   0.   0.  ]
#  [0.07 0.43 0.57 0.   0.07 0.   0.43 0.   1.   0.  ]
#  [0.1  0.94 0.52 0.   0.1  0.   0.12 0.   0.   1.  ]
#  [0.13 0.89 0.36 0.   0.2  0.   0.2  0.   1.   0.  ]]

# %% [markdown]
# #### Satandardization with z-scores

# %%
# Standardize data (0 mean, 1 stdev)
from sklearn.preprocessing import StandardScaler

# %%
array = data_cleaned4.values
scaler = StandardScaler()
scaler.fit(array)
rescaledX = scaler.transform(array)

# summarize transformed data
set_printoptions(precision=2)
print(rescaledX[0:5,:])
# Out:
# [[ 0.06  0.05 -0.73 -1.46 -1.71  0.   -1.22 -0.66 -0.67  1.25]
#  [-0.11 -0.77 -0.56 -1.46 -1.6   0.   -0.67  1.52 -0.67 -0.8 ]
#  [-0.94 -0.42  0.76 -1.46 -1.48  0.   -0.45 -0.66  1.5  -0.8 ]
#  [-0.73  1.43  0.44 -1.46 -1.37  0.   -1.77 -0.66 -0.67  1.25]
#  [-0.56  1.27 -0.39 -1.46 -1.03  0.   -1.44 -0.66  1.5  -0.8 ]]
